# %%
# Data is loaded from the 'imdb_top_2000_movies.csv' file into a pandas DataFrame named 'df'.
import pandas as pd
data_csv = 'imdb_top_2000_movies.csv'
df = pd.read_csv(data_csv)
df
# Out:
#                  Movie Name Release Year  Duration  IMDB Rating  Metascore  \
# 0             The Godfather         1972       175          9.2      100.0
# 1     The Godfather Part II         1974       202          9.0       90.0
# 2           Ordinary People         1980       124          7.7       86.0
# 3        Lawrence of Arabia         1962       218          8.3      100.0
# 4                Straw Dogs         1971       113          7.4       73.0
# ...                     ...          ...       ...          ...        ...
# 1995     The Young Victoria         2009       105          7.2       64.0
# 1996            Tooth Fairy       I 2010       101          5.0       36.0
# 1997         The Informant!         2009       108          6.5       66.0
# 1998        Youth in Revolt         2009        90          6.4       63.0
# 1999             Quarantine         2008        89          6.0       53.0
#
#           Votes                        Genre              Director  \
# 0     2,002,655                 Crime, Drama  Francis Ford Coppola
# 1     1,358,608                 Crime, Drama  Francis Ford Coppola
# 2        56,476                        Drama        Robert Redford
# 3       313,044  Adventure, Biography, Drama            David Lean
# 4        64,331       Crime, Drama, Thriller         Sam Peckinpah
# ...         ...                          ...                   ...
# 1995     66,235    Biography, Drama, History      Jean-Marc Vallée
# 1996     49,527      Comedy, Family, Fantasy       Michael Lembeck
# 1997     67,318     Biography, Comedy, Crime     Steven Soderbergh
# 1998     75,956       Comedy, Drama, Romance         Miguel Arteta
# 1999     77,075     Horror, Sci-Fi, Thriller     John Erick Dowdle
#
#                     Cast     Gross
# 0          Marlon Brando  $134.97M
# 1              Al Pacino   $57.30M
# 2      Donald Sutherland   $54.80M
# 3          Peter O'Toole   $44.82M
# 4         Dustin Hoffman       NaN
# ...                  ...       ...
# 1995         Emily Blunt   $11.00M
# 1996      Dwayne Johnson   $60.02M
# 1997          Matt Damon   $33.31M
# 1998        Michael Cera   $15.28M
# 1999  Jennifer Carpenter   $31.69M
#
# [2000 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie Name    2000 non-null   object
#  1   Release Year  2000 non-null   object
#  2   Duration      2000 non-null   int64
#  3   IMDB Rating   2000 non-null   float64
#  4   Metascore     1919 non-null   float64
#  5   Votes         2000 non-null   object
#  6   Genre         2000 non-null   object
#  7   Director      2000 non-null   object
#  8   Cast          2000 non-null   object
#  9   Gross         1903 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 156.4+ KB

# %%
df.columns
# Out:
# Index(['Movie Name', 'Release Year', 'Duration', 'IMDB Rating', 'Metascore',
#        'Votes', 'Genre', 'Director', 'Cast', 'Gross'],
#       dtype='object')

# %%
# Selects the 'IMDB Rating' and 'Gross' columns from the DataFrame 
df[['IMDB Rating', 'Gross']]
# Out:
#       IMDB Rating     Gross
# 0             9.2  $134.97M
# 1             9.0   $57.30M
# 2             7.7   $54.80M
# 3             8.3   $44.82M
# 4             7.4       NaN
# ...           ...       ...
# 1995          7.2   $11.00M
# 1996          5.0   $60.02M
# 1997          6.5   $33.31M
# 1998          6.4   $15.28M
# 1999          6.0   $31.69M
#
# [2000 rows x 2 columns]

# %%
df.describe()
# Out:
#           Duration  IMDB Rating    Metascore
# count  2000.000000  2000.000000  1919.000000
# mean    113.939000     6.922600    61.044294
# std      22.946035     0.955618    17.937722
# min      50.000000     1.500000     9.000000
# 25%      98.000000     6.400000    48.000000
# 50%     110.000000     7.000000    61.000000
# 75%     125.000000     7.600000    74.000000
# max     271.000000     9.300000   100.000000

# %%
# setting the 'Release Year' column as the index.
df_index_col = pd.read_csv(data_csv, index_col='Release Year')
df_index_col
# Out:
#                          Movie Name  Duration  IMDB Rating  Metascore  \
# Release Year
# 1972                  The Godfather       175          9.2      100.0
# 1974          The Godfather Part II       202          9.0       90.0
# 1980                Ordinary People       124          7.7       86.0
# 1962             Lawrence of Arabia       218          8.3      100.0
# 1971                     Straw Dogs       113          7.4       73.0
# ...                             ...       ...          ...        ...
# 2009             The Young Victoria       105          7.2       64.0
# I 2010                  Tooth Fairy       101          5.0       36.0
# 2009                 The Informant!       108          6.5       66.0
# 2009                Youth in Revolt        90          6.4       63.0
# 2008                     Quarantine        89          6.0       53.0
#
#                   Votes                        Genre              Director  \
# Release Year
# 1972          2,002,655                 Crime, Drama  Francis Ford Coppola
# 1974          1,358,608                 Crime, Drama  Francis Ford Coppola
# 1980             56,476                        Drama        Robert Redford
# 1962            313,044  Adventure, Biography, Drama            David Lean
# 1971             64,331       Crime, Drama, Thriller         Sam Peckinpah
# ...                 ...                          ...                   ...
# 2009             66,235    Biography, Drama, History      Jean-Marc Vallée
# I 2010           49,527      Comedy, Family, Fantasy       Michael Lembeck
# 2009             67,318     Biography, Comedy, Crime     Steven Soderbergh
# 2009             75,956       Comedy, Drama, Romance         Miguel Arteta
# 2008             77,075     Horror, Sci-Fi, Thriller     John Erick Dowdle
#
#                             Cast     Gross
# Release Year
# 1972               Marlon Brando  $134.97M
# 1974                   Al Pacino   $57.30M
# 1980           Donald Sutherland   $54.80M
# 1962               Peter O'Toole   $44.82M
# 1971              Dustin Hoffman       NaN
# ...                          ...       ...
# 2009                 Emily Blunt   $11.00M
# I 2010            Dwayne Johnson   $60.02M
# 2009                  Matt Damon   $33.31M
# 2009                Michael Cera   $15.28M
# 2008          Jennifer Carpenter   $31.69M
#
# [2000 rows x 9 columns]

# %%
# Sorts the DataFrame 'df_index_col' by the index (Release Year) in ascending order.
df_index_col.sort_index(ascending=True)
# Out:
#                                      Movie Name  Duration  IMDB Rating  \
# Release Year
# 1921                                    The Kid        68          8.2
# 1925                              The Gold Rush        95          8.1
# 1926                                The General        78          8.1
# 1927                                 Metropolis       153          8.3
# 1931          M - Eine Stadt sucht einen Mörder       117          8.3
# ...                                         ...       ...          ...
# I 2010                      Alice in Wonderland       108          6.4
# I 2010                                Grown Ups       102          6.0
# II 2004                                 Shutter        97          7.0
# II 2005                                   Chaos       106          6.4
# II 2009                                Precious       110          7.3
#
#               Metascore    Votes                       Genre  \
# Release Year
# 1921                NaN  134,277       Comedy, Drama, Family
# 1925                NaN  118,245    Adventure, Comedy, Drama
# 1926                NaN   97,801   Action, Adventure, Comedy
# 1927               98.0  184,838               Drama, Sci-Fi
# 1931                NaN  167,883    Crime, Mystery, Thriller
# ...                 ...      ...                         ...
# I 2010             53.0  439,658  Adventure, Family, Fantasy
# I 2010             30.0  274,486                      Comedy
# II 2004             NaN   48,945   Horror, Mystery, Thriller
# II 2005             NaN   57,717        Action, Crime, Drama
# II 2009            78.0  116,011                       Drama
#
#                            Director               Cast     Gross
# Release Year
# 1921                Charles Chaplin    Charles Chaplin    $5.45M
# 1925                Charles Chaplin    Charles Chaplin    $5.45M
# 1926                 Clyde Bruckman      Buster Keaton    $1.03M
# 1927                     Fritz Lang      Brigitte Helm    $1.24M
# 1931                     Fritz Lang        Peter Lorre    $0.03M
# ...                             ...                ...       ...
# I 2010                   Tim Burton     Mia Wasikowska  $334.19M
# I 2010                 Dennis Dugan       Adam Sandler  $162.00M
# II 2004       Banjong Pisanthanakun  Parkpoom Wongpoom       NaN
# II 2005                 Tony Giglio      Jason Statham       NaN
# II 2009                 Lee Daniels    Gabourey Sidibe   $47.57M
#
# [2000 rows x 9 columns]

# %%
# Counts the number of missing values (NaN) in each column of the DataFrame
df.isnull().sum()
# Out:
# Movie Name       0
# Release Year     0
# Duration         0
# IMDB Rating      0
# Metascore       81
# Votes            0
# Genre            0
# Director         0
# Cast             0
# Gross           97
# dtype: int64

# %%
# Creates a  filter to select rows from the DataFrame where the 'IMDB Rating' is greater than or equal to 7.0 and the 'Genre' column contains the 'Thriller'.
filt = (df['IMDB Rating'] >= 7.0) & (df['Genre'].str.contains('Thriller', na=False))
filt
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
# Selects rows from the DataFrame where the boolean filter 'filt' evaluates to True
df.loc[filt]
# Out:
#             Movie Name Release Year  Duration  IMDB Rating  Metascore  \
# 4           Straw Dogs         1971       113          7.4       73.0
# 10              Psycho         1960       109          8.5       97.0
# 19    The Conversation         1974       113          7.7       87.0
# 20             Vertigo         1958       128          8.3      100.0
# 23         Deliverance         1972       109          7.7       80.0
# ...                ...          ...       ...          ...        ...
# 1917      Body of Lies         2008       128          7.0       57.0
# 1922            Orphan         2009       123          7.0       42.0
# 1943       Unthinkable         2010        97          7.0        NaN
# 1948          Brothers       I 2009       105          7.1       58.0
# 1954        Kynodontas         2009        97          7.2       73.0
#
#         Votes                       Genre              Director  \
# 4      64,331      Crime, Drama, Thriller         Sam Peckinpah
# 10    715,718   Horror, Mystery, Thriller      Alfred Hitchcock
# 19    121,187    Drama, Mystery, Thriller  Francis Ford Coppola
# 20    425,385  Mystery, Romance, Thriller      Alfred Hitchcock
# 23    118,842  Adventure, Drama, Thriller          John Boorman
# ...       ...                         ...                   ...
# 1917  238,908     Action, Drama, Thriller          Ridley Scott
# 1922  251,131   Horror, Mystery, Thriller    Jaume Collet-Serra
# 1943   93,233      Crime, Drama, Thriller         Gregor Jordan
# 1948  145,494        Drama, Thriller, War          Jim Sheridan
# 1954  109,503             Drama, Thriller      Yorgos Lanthimos
#
#                       Cast    Gross
# 4           Dustin Hoffman      NaN
# 10         Anthony Perkins  $32.00M
# 19            Gene Hackman   $4.42M
# 20           James Stewart   $3.20M
# 23              Jon Voight   $7.06M
# ...                    ...      ...
# 1917     Leonardo DiCaprio  $39.39M
# 1922          Vera Farmiga  $41.60M
# 1943     Samuel L. Jackson      NaN
# 1948       Jake Gyllenhaal  $28.50M
# 1954  Christos Stergioglou   $0.11M
#
# [152 rows x 10 columns]

# %%
# Selects specific columns ('Movie Name' and 'IMDB Rating') from the DataFrame where the boolean filter 'filt' evaluates to True
df.loc[filt, ['Movie Name', 'IMDB Rating']]
# Out:
#             Movie Name  IMDB Rating
# 4           Straw Dogs          7.4
# 10              Psycho          8.5
# 19    The Conversation          7.7
# 20             Vertigo          8.3
# 23         Deliverance          7.7
# ...                ...          ...
# 1917      Body of Lies          7.0
# 1922            Orphan          7.0
# 1943       Unthinkable          7.0
# 1948          Brothers          7.1
# 1954        Kynodontas          7.2
#
# [152 rows x 2 columns]

# %%
# Sorts the DataFrame 'df' by two columns, 'IMDB Rating' in descending order and 'Gross' in ascending order, creating a new DataFrame named 'df_sorted'
df_sorted = df.sort_values(by=['IMDB Rating', 'Gross'], ascending=[False, True])

# %%
# Displays the top 10 rows of the DataFrame 'df_sorted', showing movies with the highest IMDb ratings and lowest gross earnings.
df_sorted.head(10)
# Out:
#                                              Movie Name Release Year  \
# 506                            The Shawshank Redemption         1994
# 0                                         The Godfather         1972
# 1019      The Lord of the Rings: The Return of the King         2003
# 36                                         12 Angry Men         1957
# 1508                                    The Dark Knight         2008
# 1                                 The Godfather Part II         1974
# 513                                    Schindler's List         1993
# 580                                        Pulp Fiction         1994
# 1018  The Lord of the Rings: The Fellowship of the Ring         2001
# 1755                                          Inception         2010
#
#       Duration  IMDB Rating  Metascore      Votes                      Genre  \
# 506        142          9.3       82.0  2,875,249                      Drama
# 0          175          9.2      100.0  2,002,655               Crime, Drama
# 1019       201          9.0       94.0  1,970,311   Action, Adventure, Drama
# 36          96          9.0       97.0    860,130               Crime, Drama
# 1508       152          9.0       84.0  2,857,781       Action, Crime, Drama
# 1          202          9.0       90.0  1,358,608               Crime, Drama
# 513        195          9.0       95.0  1,444,171  Biography, Drama, History
# 580        154          8.9       95.0  2,209,021               Crime, Drama
# 1018       178          8.9       92.0  1,998,243   Action, Adventure, Drama
# 1755       148          8.8       74.0  2,538,581  Action, Adventure, Sci-Fi
#
#                   Director               Cast     Gross
# 506         Frank Darabont        Tim Robbins   $28.34M
# 0     Francis Ford Coppola      Marlon Brando  $134.97M
# 1019         Peter Jackson        Elijah Wood  $377.85M
# 36            Sidney Lumet        Henry Fonda    $4.36M
# 1508     Christopher Nolan     Christian Bale  $534.86M
# 1     Francis Ford Coppola          Al Pacino   $57.30M
# 513       Steven Spielberg        Liam Neeson   $96.90M
# 580      Quentin Tarantino      John Travolta  $107.93M
# 1018         Peter Jackson        Elijah Wood  $315.54M
# 1755     Christopher Nolan  Leonardo DiCaprio  $292.58M

# %%
# Displays the bottom 10 rows of the DataFrame 'df_sorted', showing movies with the lowest IMDb ratings and highest gross earnings.
df_sorted.tail(10)
# Out:
#                          Movie Name Release Year  Duration  IMDB Rating  \
# 978               Battlefield Earth         2000       117          2.5
# 1977           Dragonball Evolution         2009        85          2.5
# 1727                     Epic Movie         2007        86          2.4
# 1199                        Glitter         2001       104          2.4
# 1452              Alone in the Dark         2005        99          2.4
# 1738                 Çilgin Dersane         2007       100          1.9
# 1931     Birdemic: Shock and Terror         2010       105          1.7
# 1492     Keloglan Karaprens'e Karsi         2006       105          1.6
# 1736  Dünyayi Kurtaran Adam'in Oglu         2006       110          1.5
# 1737       Emret Komutanim: Sah Mat         2007       100          1.5
#
#       Metascore    Votes                       Genre            Director  \
# 978         9.0   82,944   Action, Adventure, Sci-Fi     Roger Christian
# 1977       45.0   79,178  Action, Adventure, Fantasy          James Wong
# 1727       17.0  109,380  Adventure, Comedy, Fantasy     Jason Friedberg
# 1199       14.0   24,070       Drama, Music, Romance  Vondie Curtis-Hall
# 1452        9.0   46,944      Action, Horror, Sci-Fi            Uwe Boll
# 1738        NaN    3,924                      Comedy         Faruk Aksoy
# 1931        NaN   25,394            Horror, Thriller        James Nguyen
# 1492        NaN    9,651                      Comedy      Tayfun Güneyer
# 1736        NaN   16,754      Action, Comedy, Sci-Fi        Kartal Tibet
# 1737        NaN    7,058   Action, Adventure, Comedy      Taner Akvardar
#
#                    Cast    Gross
# 978       John Travolta  $21.47M
# 1977     Justin Chatwin   $9.35M
# 1727      Aaron Seltzer  $39.74M
# 1199       Mariah Carey   $4.27M
# 1452   Christian Slater   $5.18M
# 1738         Alp Kirsan      NaN
# 1931          Alan Bagh      NaN
# 1492   Mehmet Ali Erbil      NaN
# 1736       Alpcan Alpar      NaN
# 1737  Mustafa Altioklar      NaN

# %%
# Calculates various descriptive statistics and extracts subsets of movie durations from the DataFrame 'df'.
duration_count = df.Duration.count()
duration_mean = df.Duration.mean()
duration_standard_deviation = df.Duration.std()
duration_median = df.Duration.median()
duration_min = df.Duration.min()
duration_max = df.Duration.max()
largest_duration_movies = df.Duration.nlargest(10)
smallest_duration_movies = df.Duration.nsmallest(10)

# %%
# Displays various descriptive statistics for the 'Duration' column in the DataFrame
print(f'Duration Count = {duration_count}')
print(f'Duration Mean = {duration_mean}')
print(f'Duration Standard Diviation = {duration_standard_deviation}')
print(f'Duration Median = {duration_median}')
print(f'Duration Min = {duration_min}')
print(f'Duration Max = {duration_max}')
# Out:
# Duration Count = 2000
# Duration Mean = 113.939
# Duration Standard Diviation = 22.946035371489227
# Duration Median = 110.0
# Duration Min = 50
# Duration Max = 271

# %%
# Groups the DataFrame 'df' by the 'Genre' column, creating a DataFrameGroupBy object named 'genre_group'.
genre_group = df.groupby(['Genre'])
genre_group

# %%
# Calculates the mean duration of movies in the 'Drama' genre using the grouped DataFrame 'genre_group' and prints the result.
drama_duration_mean = genre_group['Duration'].mean().Drama
print(f'Drama mean duration = {drama_duration_mean}')
# Out:
# Drama mean duration = 128.31147540983608

# %%
# Calculates the minimum duration of movies in the 'Horror' genre using the grouped DataFrame 'genre_group' and prints the result.
horror_duration_min = genre_group['Duration'].min().Horror
print(f'Horror Minimal Duration = {horror_duration_min}')
# Out:
# Horror Minimal Duration = 82

# %%
# Calculates the maximum duration of movies in the 'Comedy' genre using the grouped DataFrame 'genre_group' and prints the result.
comedy_duration_max = genre_group['Duration'].max().Comedy
print(f'Comedy Maximal Duration = {comedy_duration_max}')
# Out:
# Comedy Maximal Duration = 118

# %%
# Selects rows from the DataFrame corresponding to the movies with the largest durations.
df.loc[largest_duration_movies]
# Out:
#               Movie Name Release Year  Duration  IMDB Rating  Metascore  \
# 271            The Thing         1982       109          8.2       57.0
# 242         Endless Love         1981       116          4.9       30.0
# 238            Excalibur         1981       140          7.3       56.0
# 229    Where Eagles Dare         1968       158          7.6       63.0
# 224          Logan's Run         1976       119          6.8       53.0
# 220            King Kong         1933       100          7.9       92.0
# 218     Sunset Boulevard         1950       110          8.4       94.0
# 212              The Kid         1921        68          8.2        NaN
# 210  Ladri di biciclette         1948        89          8.3        NaN
# 210  Ladri di biciclette         1948        89          8.3        NaN
#
#        Votes                      Genre           Director  \
# 271  464,271    Horror, Mystery, Sci-Fi     John Carpenter
# 242    9,520             Drama, Romance  Franco Zeffirelli
# 238   66,890  Adventure, Drama, Fantasy       John Boorman
# 229   62,696     Action, Adventure, War    Brian G. Hutton
# 224   60,814  Action, Adventure, Sci-Fi   Michael Anderson
# 220   90,579          Adventure, Horror   Merian C. Cooper
# 218  235,594           Drama, Film-Noir       Billy Wilder
# 212  134,277      Comedy, Drama, Family    Charles Chaplin
# 210  174,520                      Drama   Vittorio De Sica
# 210  174,520                      Drama   Vittorio De Sica
#
#                      Cast    Gross
# 271          Kurt Russell  $13.78M
# 242        Brooke Shields  $31.18M
# 238           Nigel Terry  $34.97M
# 229        Richard Burton      NaN
# 224          Michael York  $25.00M
# 220  Ernest B. Schoedsack  $10.00M
# 218        William Holden      NaN
# 212       Charles Chaplin   $5.45M
# 210   Lamberto Maggiorani   $0.33M
# 210   Lamberto Maggiorani   $0.33M

# %%
# Selects rows from the DataFrame corresponding to the movies with the smallest durations.
df.loc[smallest_duration_movies]
# Out:
#                          Movie Name Release Year  Duration  IMDB Rating  \
# 50                             Jaws         1975       124          8.1
# 60                          Serpico         1973       130          7.7
# 64  Monty Python and the Holy Grail         1975        91          8.2
# 68               Young Frankenstein         1974       106          8.0
# 69                 The Great Escape         1963       172          8.2
# 69                 The Great Escape         1963       172          8.2
# 75                           Lolita         1962       153          7.5
# 75                           Lolita         1962       153          7.5
# 76            From Here to Eternity         1953       118          7.6
# 77     Mr. Smith Goes to Washington         1939       129          8.1
#
#     Metascore    Votes                         Genre          Director  \
# 50       87.0  656,761  Adventure, Mystery, Thriller  Steven Spielberg
# 60       83.0  134,207       Biography, Crime, Drama      Sidney Lumet
# 64       91.0  568,591    Adventure, Comedy, Fantasy     Terry Gilliam
# 68       83.0  168,404                        Comedy        Mel Brooks
# 69       86.0  258,019    Adventure, Drama, Thriller      John Sturges
# 69       86.0  258,019    Adventure, Drama, Thriller      John Sturges
# 75       79.0  108,444         Crime, Drama, Romance   Stanley Kubrick
# 75       79.0  108,444         Crime, Drama, Romance   Stanley Kubrick
# 76       85.0   50,657           Drama, Romance, War    Fred Zinnemann
# 77       73.0  121,085                 Comedy, Drama       Frank Capra
#
#               Cast     Gross
# 50    Roy Scheider  $260.00M
# 60       Al Pacino   $29.80M
# 64     Terry Jones    $1.23M
# 68     Gene Wilder   $86.30M
# 69   Steve McQueen   $12.10M
# 69   Steve McQueen   $12.10M
# 75     James Mason    $9.25M
# 75     James Mason    $9.25M
# 76  Burt Lancaster   $30.50M
# 77   James Stewart    $9.60M

# %%
# Imports necessary libraries for plotting: NumPy, Matplotlib, and Seaborn and suppresses warnings for cleaner output.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
sns.set_style("darkgrid")
warnings.filterwarnings("ignore")

# %%
### Barplot Orientation is a problem ###
# Plots a bar chart showing the top 10 movies by gross earnings. The movies are sorted in ascending order of gross earnings and 
# displayed with their corresponding gross earnings. 
plt.figure(figsize=(14, 6))

data = df.sort_values(by='Gross', ascending=False).head(10).sort_values(by='Gross', ascending=True)

sns.barplot(data=data, y='Movie Name', x='Gross', palette="viridis")

plt.title("Top 10 Movies By Gross")
plt.xlabel("Gross Earnings")
plt.ylabel("Movie Name")
plt.tight_layout()
plt.show()

# %%
### Barplot Orientation is a problem ###
# Drop rows with NaN values in the 'Gross' column and get the top 10 movies based on gross earnings
top_10_gross_movies = df.dropna(subset=['Gross']).sort_values(by='Gross', ascending=True).tail(10)

# Set up the figure and axes
plt.figure(figsize=(14, 6))

# Create the barplot
sns.barplot(data=top_10_gross_movies, x='Gross', y='Movie Name', palette='viridis')

# Set labels and title
plt.xlabel('Gross Earnings')
plt.ylabel('Movie Name')
plt.title('Top 10 Movies by Gross Earnings')
plt.tight_layout()
plt.show()

# %%
# Plots a bar chart displaying the top 10 genres based on their frequency in the dataset. The subplot is positioned on the right side of the figure
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 2)
top10_genres = df['Genre'].value_counts().head(10)
sns.barplot(x=top10_genres.values, y=top10_genres.index, palette='viridis')
plt.title('Top 10 Genres')

plt.tight_layout()
plt.show()

# %%
# Creates a figure with two subplots: a histogram of movie durations on the left and a boxplot of movie durations on the right.
fig, axs = plt.subplots(1, 2, figsize=(18, 8))

# Plot histogram of movie durations
axs[0].hist(df['Duration'], bins=30, color='purple', edgecolor='black')
axs[0].set_xlabel('Duration')
axs[0].set_ylabel('Minutes')
axs[0].set_title('Distribution of Movie Duration')

# Plot boxplot of movie durations
sns.boxplot(data=df['Duration'], ax=axs[1], palette='Set1')
axs[1].set_xlabel('Duration')
axs[1].set_ylabel('Minutes')
axs[1].set_title('Boxplot of Movie Duration')

plt.tight_layout()
plt.show()

# %%
# Creates a figure with two subplots arranged vertically: the first subplot displays the counts of Metascores, 
# and the second subplot displays the counts of IMDb ratings
fig, axs = plt.subplots(2, 1, figsize=(20, 10))

# Plot for Metascore data
df['Metascore'].value_counts().sort_index().plot(kind='line', marker='o', color='green', ax=axs[0])
axs[0].set_title('Metascore Counts')
axs[0].set_xlabel('Metascores')
axs[0].set_ylabel('Count')

# Plot for IMDb Rating data
df['IMDB Rating'].value_counts().sort_index().plot(kind='line', marker='o', color='blue', ax=axs[1])
axs[1].set_title('IMDB Rating Counts')
axs[1].set_xlabel('IMDB Ratings')
axs[1].set_ylabel('Count')

plt.tight_layout()
plt.show()
